# %%
import pandas as pd

from classes import get_league_v4_entries_by_queue_tier_division as getv4
from tests.settings import API_KEY 

response = getv4('EUW1',"RANKED_SOLO_5x5", "DIAMOND", "I", 1, API_KEY)
response_df = pd.DataFrame(response)
response_df.head(5)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
# ----> 3 from classes import get_league_v4_entries_by_queue_tier_division as getv4
#       4 from tests.settings import API_KEY
#       6 response = getv4('EUW1',"RANKED_SOLO_5x5", "DIAMOND", "I", 1, API_KEY)
#
# ModuleNotFoundError: No module named 'classes'

# %%
# Out:
# RangeIndex(start=0, stop=0, step=1)
