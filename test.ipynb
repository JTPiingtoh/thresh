# %%
import pandas as pd

from classes import get_league_v4_entries_by_queue_tier_division as getv4
from tests.settings import API_KEY 

response = getv4('EUW1',"RANKED_SOLO_5x5", "DIAMOND", "I", 1, API_KEY)
response_df = pd.DataFrame(response)
response_df.head(5)
# Out:
#                                leagueId        queueType     tier rank  \
# 0  7a2f2be0-f731-412a-8420-41f24d92b1ef  RANKED_SOLO_5x5  DIAMOND    I
# 1  d21ba54b-fc07-4544-ac5c-bf096ade43c9  RANKED_SOLO_5x5  DIAMOND    I
# 2  3fa1723a-f0c3-4c17-b998-14885db49c58  RANKED_SOLO_5x5  DIAMOND    I
# 3  50c74e9e-0207-4c9c-bb9e-7431d6ba1c71  RANKED_SOLO_5x5  DIAMOND    I
# 4  1a834434-5dd6-4fcc-bdf7-21d755699143  RANKED_SOLO_5x5  DIAMOND    I
#
#                                                puuid  leaguePoints  wins  \
# 0  RpktJayhtP_6HYunDbRK-k7h8ZYF5OAE0wKPMSIAtHy2Ux...            75   376
# 1  jY-0cbEBlA_0_ZffJkDIKfxM7x4PLxpEOsx9Xxj2Y6x-ve...            75    52
# 2  EXT-c2iS8-UMLCPcLahuW4JhqYfzOkqDAqoJ2gDoQk0dxy...            10   904
# 3  w-ql3GhVjzfnmxuQAZT-hdBEqFipopW_eNfGW9Hh862v2_...            51    49
# 4  CbHP8JEqmkoe8gny84thjMz00ogqeumHHCxjNSegCSKkxk...            75   163
#
#    losses  veteran  inactive  freshBlood  hotStreak
# 0     358    False     False       False      False
# 1      33    False     False       False      False
# 2     892    False     False       False      False
# 3      33    False     False       False      False
# 4     147    False     False       False      False

# %%
# Out:
# RangeIndex(start=0, stop=0, step=1)
