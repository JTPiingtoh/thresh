# %%
import pandas as pd

from classes import get_league_v4_entries_by_queue_tier_division as getv4

API_KEY = "RGAPI-3da2b500-d522-44d5-95c1-9ff3c923ce00"

response = getv4('EUW1',"RANKED_SOLO_5x5", "DIAMOND", "I", 1, API_KEY)
response_df = pd.DataFrame(response)
response_df.head(5)
# Out:
#                                leagueId        queueType     tier rank  \
# 0  7e18d1b4-b910-4776-8982-785015a62e8e  RANKED_SOLO_5x5  DIAMOND    I
# 1  f2183252-7828-477b-9b0c-1a19def79d02  RANKED_SOLO_5x5  DIAMOND    I
# 2  93f4ad3e-b4eb-46f3-a781-476285fee1a7  RANKED_SOLO_5x5  DIAMOND    I
# 3  6538e195-541f-436b-b950-19b0f2d6240b  RANKED_SOLO_5x5  DIAMOND    I
# 4  fb4bd430-7e29-47e9-ad80-dbae6e3ee0c9  RANKED_SOLO_5x5  DIAMOND    I
#
#                                                puuid  leaguePoints  wins  \
# 0  gUFal2HxxhIZ1eMln6XS0xno_V48-jxEdeEnj2JT37kBDx...            36    39
# 1  IwdqkBQC0jzTV4q0_XTndoHHUsBVs-2vfkIgzqNT_lxS2I...            15    39
# 2  pZXMbtv46_HKJ-FEK70DHx31awEOwNXkJ4JbHXcNK3ZkxK...            49    35
# 3  bsUVgCbkUahRRaH7sewbN3KGeslOy8uif5up630v45GLhO...            35    76
# 4  Y6aVH57b9VERhNUES3PkSQNJ5Ngdwv70N3Hv8gfMcW5ugq...            78    21
#
#    losses  veteran  inactive  freshBlood  hotStreak
# 0      31    False     False       False      False
# 1      43    False     False        True      False
# 2      37    False     False       False      False
# 3      63    False     False       False       True
# 4      21    False     False       False      False

# %%
response_df["leagueId"]
# Out:
# 0      7e18d1b4-b910-4776-8982-785015a62e8e
# 1      f2183252-7828-477b-9b0c-1a19def79d02
# 2      93f4ad3e-b4eb-46f3-a781-476285fee1a7
# 3      6538e195-541f-436b-b950-19b0f2d6240b
# 4      fb4bd430-7e29-47e9-ad80-dbae6e3ee0c9
#                        ...
# 200    dfaafa40-2801-4987-8f96-02256bbe085f
# 201    e38d360a-c60c-42e9-8ba7-dde0af2eb4d9
# 202    90944af2-d113-4ebc-be3f-661a2df72b22
# 203    838c1e69-56a5-47a9-ba5a-7c0b5921b3ce
# 204    7d455e57-d9cf-4482-9c6c-d5e5d96701b9
# Name: leagueId, Length: 205, dtype: str
